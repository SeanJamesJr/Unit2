# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Lesson 1
#
# My name is Jeff

# %%
import matplotlib.pyplot as plt

y=[1,2,3,4]
x= [22,87,0,18]
plt.plot(x,y)
plt.ylabel('memes')
plt.xlabel('Derp')
plt.title("potato")
# Out:
# Text(0.5, 1.0, 'potato')

# %% [markdown]
# Bar Graph

# %%
y=[1,2,3,4,5]
x= [30,45,78,100,15]
plt.bar(x,y)
plt.ylabel('memes')
plt.xlabel('Derp')
plt.title("potato")
# Out:
# Text(0.5, 1.0, 'potato')

# %%
labels= 'waffle','bacon','eggs','sausge'
sizes= [15,45,10,20]

fig, ax =plt.subplots()
ax.pie(sizes, labels=labels)
plt.title('which is better from a unanmous vote')
# Out:
# Text(0.5, 1.0, 'which is better from a unanmous vote')
